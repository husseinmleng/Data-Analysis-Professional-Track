# %% [markdown]
# # Python Libraries

# %%
# One of the easiest way to import libraries
import numpy as np

# %%
var1 = np.array([[1,2],[3,4]])

# %%
var1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#alternate way to import libraries
from numpy import *

# %%
var2 = array([[1,2],[3,4]])

# %%
var2
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
# Importing specific function instead of all (*)
from math import exp
exp(3) # Calculates Exponential
# Out:
# 20.085536923187668
